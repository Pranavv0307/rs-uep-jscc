# %%
import os
os.chdir('/kaggle/working')

if not os.path.exists('/kaggle/working/rs-uep-jscc'):
    # !git clone https://github.com/Pranavv0307/rs-uep-jscc

os.chdir('/kaggle/working/rs-uep-jscc')
# Out:
# Cloning into 'rs-uep-jscc'...
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 19 (delta 0), reused 19 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (19/19), 5.86 KiB | 5.86 MiB/s, done.

# %%
# !pip install -q pyyaml scikit-image tensorboard

# %%
import torch
print(torch.cuda.is_available(), torch.cuda.get_device_name(0) if torch.cuda.is_available() else "NO GPU")
# Out:
# True Tesla T4

# %%
# !git pull origin main
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 2), reused 4 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 322 bytes | 322.00 KiB/s, done.
# From https://github.com/Pranavv0307/rs-uep-jscc
#  * branch            main       -> FETCH_HEAD
#    faeee6d..e625b06  main       -> origin/main
# Updating faeee6d..e625b06
# Fast-forward
#  configs/week1_overfit.yaml | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
import wandb
wandb.login(key=UserSecretsClient().get_secret("WANDB_API_KEY"))

# %%
# !PYTHONPATH=. python experiments/overfit_test.py --config configs/week1_overfit.yaml --data_dir /kaggle/working/cifar10_data --snr_db 25
# Out:
# Using device: cuda
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: mithileshyechuri03 (mithileshyechuri03-international-institute-of-informatio) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: Tracking run with wandb version 0.26.1
# wandb: Run data is saved locally in /kaggle/working/rs-uep-jscc/wandb/run-20260813_090509-fjfs7iio
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run week1-overfit-snr25.0
# wandb: ⭐️ View project at https://wandb.ai/mithileshyechuri03-international-institute-of-informatio/rs-uep-jscc
# wandb: 🚀 View run at https://wandb.ai/mithileshyechuri03-international-institute-of-informatio/rs-uep-jscc/runs/fjfs7iio
# channel SNR = 25.0 dB (overridden from CLI)
# k = 512 channel symbols (ratio 0.1667)
# epoch     1 | MSE 0.067006 | PSNR 11.74 dB
# ...

# %%
# !PYTHONPATH=. pytest tests/ -v
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /kaggle/working/rs-uep-jscc
# plugins: anyio-4.13.0, typeguard-4.5.1, langsmith-0.7.34
# collected 3 items
#
# tests/test_pipeline.py::test_shapes_roundtrip PASSED                     [ 33%]
# tests/test_pipeline.py::test_power_constraint PASSED                     [ 66%]
# tests/test_pipeline.py::test_output_range PASSED                         [100%]
#
# ============================== 3 passed in 1.85s ===============================

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
